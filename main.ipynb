# %%
# only necessary for google colab! to load models into session
# !git clone https://github.com/jyjblrd/S4_Slicer
# !mv S4_Slicer/* ./

# %%
# !pip install tetgen
# !pip install trame
# !pip install pyvista
# !pip install scipy
# !pip install open3d
# !pip install pygcode
# !apt-get install -qq xvfb libgl1-mesa-glx
# !pip install pyvista -qq
# !pip install tqdm
# !pip install cupy-cuda12x
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tetgen in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.7.0)
# Requirement already satisfied: numpy<3,>=2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tetgen) (2.4.0)
# Requirement already satisfied: pyvista>=0.31.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tetgen) (0.46.4)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista>=0.31.0->tetgen) (3.10.8)
# Requirement already satisfied: pillow in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista>=0.31.0->tetgen) (12.0.0)
# Requirement already satisfied: pooch in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista>=0.31.0->tetgen) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista>=0.31.0->tetgen) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.10 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista>=0.31.0->tetgen) (4.15.0)
# Requirement already satisfied: vtk!=9.4.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista>=0.31.0->tetgen) (9.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch->pyvista>=0.31.0->tetgen) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch->pyvista>=0.31.0->tetgen) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista>=0.31.0->tetgen) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista>=0.31.0->tetgen) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista>=0.31.0->tetgen) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista>=0.31.0->tetgen) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista>=0.31.0->tetgen) (2025.11.12)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: trame in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.12.0)
# Requirement already satisfied: trame-server<4,>=3.4 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trame) (3.9.0)
# Requirement already satisfied: trame-client<4,>=3.10.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trame) (3.11.2)
# Requirement already satisfied: trame-common<2,>=1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trame) (1.1.0)
# Requirement already satisfied: wslink>=2.3.3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trame) (2.5.0)
# Requirement already satisfied: pyyaml in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trame) (6.0.3)
# Requirement already satisfied: more-itertools in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from trame-server<4,>=3.4->trame) (10.8.0)
# Requirement already satisfied: aiohttp<4 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wslink>=2.3.3->trame) (3.13.2)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wslink>=2.3.3->trame) (1.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4->wslink>=2.3.3->trame) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiosignal>=1.4.0->aiohttp<4->wslink>=2.3.3->trame) (4.15.0)
# Requirement already satisfied: idna>=2.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4->wslink>=2.3.3->trame) (3.11)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyvista in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.46.4)
# Requirement already satisfied: matplotlib>=3.0.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (3.10.8)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (2.4.0)
# Requirement already satisfied: pillow in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (12.0.0)
# Requirement already satisfied: pooch in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (1.8.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.10 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (4.15.0)
# Requirement already satisfied: vtk!=9.4.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyvista) (9.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.1->pyvista) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch->pyvista) (4.5.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pooch->pyvista) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.1->pyvista) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.19.0->pooch->pyvista) (2025.11.12)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scipy) (2.4.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: open3d in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.19.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (2.4.0)
# Requirement already satisfied: dash>=2.6.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (3.3.0)
# Requirement already satisfied: werkzeug>=3.0.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (3.1.4)
# Requirement already satisfied: flask>=3.0.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (3.1.2)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (5.10.4)
# Requirement already satisfied: configargparse in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (1.7.1)
# Requirement already satisfied: ipywidgets>=8.0.4 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from open3d) (8.1.8)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (6.5.0)
# Requirement already satisfied: importlib-metadata in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (8.7.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (4.15.0)
# Requirement already satisfied: requests in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (2.32.5)
# Requirement already satisfied: retrying in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from dash>=2.6.0->open3d) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask>=3.0.0->open3d) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask>=3.0.0->open3d) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask>=3.0.0->open3d) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask>=3.0.0->open3d) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from flask>=3.0.0->open3d) (3.0.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=8.0.4->open3d) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=8.0.4->open3d) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=8.0.4->open3d) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=8.0.4->open3d) (3.0.16)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat>=5.7.0->open3d) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat>=5.7.0->open3d) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat>=5.7.0->open3d) (5.9.1)
# Requirement already satisfied: colorama in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click>=8.1.3->flask>=3.0.0->open3d) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.5.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (2.14.0)
# Requirement already satisfied: packaging in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->dash>=2.6.0->open3d) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->dash>=2.6.0->open3d) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->dash>=2.6.0->open3d) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->dash>=2.6.0->open3d) (2025.11.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pygcode in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.2.1)
# Collecting argparse (from pygcode)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: euclid3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pygcode) (0.1)
# Requirement already satisfied: six in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pygcode) (1.17.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# 'apt-get' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
import networkx as nx
import numpy as np
import pyvista as pv
import tetgen
from scipy.optimize import minimize, least_squares
from scipy.spatial.transform import Rotation as R
import open3d as o3d
import time
import pickle
import base64
from tqdm.notebook import tqdm  # Ajout de tqdm pour Jupyter

pv.set_jupyter_backend('trame') # Google colab only allows static rendering. Download and run notepad locally to view in 3D!
pv.global_theme.notebook = True

def encode_object(obj):
    return base64.b64encode(pickle.dumps(obj)).decode('utf-8')

def decode_object(encoded_str):
    return pickle.loads(base64.b64decode(encoded_str))

up_vector = np.array([0, 0, 1])

# Load mesh
model_name = "pi 3mm"
mesh = o3d.io.read_triangle_mesh(f'input_models/{model_name}.stl')

# convert to tetrahedral mesh
input_tet = tetgen.TetGen(np.asarray(mesh.vertices), np.asarray(mesh.triangles))
# input_tet.make_manifold() # comment out if not needed
input_tet.tetrahedralize()
input_tet = input_tet.grid

PART_OFFSET = np.array([0., 0., 0.])
x_min, x_max, y_min, y_max, z_min, z_max = input_tet.bounds
input_tet.points -= np.array([(x_min + x_max) / 2, (y_min + y_max) / 2, z_min]) + PART_OFFSET

# find neighbours
cell_neighbour_dict = {neighbour_type: {face: [] for face in range(input_tet.number_of_cells)} for neighbour_type in ["point", "edge", "face"]}
for neighbour_type in tqdm(["point", "edge", "face"], desc="Recherche des voisins"):
    cell_neighbours = []
    for cell_index in range(input_tet.number_of_cells):
        neighbours = input_tet.cell_neighbors(cell_index, f"{neighbour_type}s")
        for neighbour in neighbours:
            if neighbour > cell_index:
                cell_neighbours.append((cell_index, neighbour))
    for face_1, face_2 in np.array(cell_neighbours):
        cell_neighbour_dict[neighbour_type][face_1].append(face_2)
        cell_neighbour_dict[neighbour_type][face_2].append(face_1)

    input_tet.field_data[f"cell_{neighbour_type}_neighbours"] = np.array(cell_neighbours)

cell_neighbour_graph = nx.Graph()
cell_centers = input_tet.cell_centers().points
for edge in tqdm(input_tet.field_data["cell_point_neighbours"], desc="Création du graphe de proximité"): 
    distance = np.linalg.norm(cell_centers[edge[0]] - cell_centers[edge[1]])
    cell_neighbour_graph.add_weighted_edges_from([(edge[0], edge[1], distance)])

def update_tet_attributes(tet):
    '''
    Calculate face normals, face centers, cell centers, and overhang angles for each cell in the tetrahedral mesh.
    '''
    surface_mesh = tet.extract_surface()
    cell_to_face = decode_object(tet.field_data["cell_to_face"])

    # put general data in field_data for easy access
    cells = tet.cells.reshape(-1, 5)[:, 1:] # assume all cells have 4 vertices
    tet.add_field_data(cells, "cells")
    cell_vertices = tet.points
    tet.add_field_data(cell_vertices, "cell_vertices")
    faces = surface_mesh.faces.reshape(-1, 4)[:, 1:] # assume all faces have 3 vertices
    tet.add_field_data(faces, "faces")
    face_vertices = surface_mesh.points
    tet.add_field_data(face_vertices, "face_vertices")

    tet.cell_data['face_normal'] = np.full((tet.number_of_cells, 3), np.nan)
    surface_mesh_face_normals = surface_mesh.face_normals
    for cell_index, face_indices in tqdm(cell_to_face.items(), desc="Calcul des normales", leave=False):
        face_normals = surface_mesh_face_normals[face_indices]
        # get the normal facing the most down
        most_down_normal_index = np.argmin(face_normals[:, 2])
        tet.cell_data['face_normal'][cell_index] = face_normals[most_down_normal_index]
    tet.cell_data['face_normal'] =  tet.cell_data['face_normal'] / np.linalg.norm(tet.cell_data['face_normal'], axis=1)[:, None]

    tet.cell_data['face_center'] = np.empty((tet.number_of_cells, 3))
    tet.cell_data['face_center'][:,:] = np.nan
    surface_mesh_cell_centers = surface_mesh.cell_centers().points
    for cell_index, face_indices in tqdm(cell_to_face.items(), desc="Centres des faces", leave=False):
        face_centers = surface_mesh_cell_centers[face_indices]
        # get the normal facing the most down
        most_down_center_index = np.argmin(face_centers[:, 2])
        tet.cell_data['face_center'][cell_index] = face_centers[most_down_center_index]

    tet.cell_data["cell_center"] = tet.cell_centers().points

    # calculate bottom cells
    bottom_cell_threshold = np.nanmin(tet.cell_data['face_center'][:, 2])+0.3
    bottom_cells_mask = tet.cell_data['face_center'][:, 2] < bottom_cell_threshold
    tet.cell_data['is_bottom'] = bottom_cells_mask
    bottom_cells = np.where(bottom_cells_mask)[0]

    face_normals = tet.cell_data['face_normal'].copy()
    face_normals[bottom_cells_mask] = np.nan # make bottom faces not angled
    overhang_angle = np.arccos(np.dot(face_normals, up_vector))
    tet.cell_data['overhang_angle'] = overhang_angle

    overhang_direction = face_normals[:, :2].copy()
    overhang_direction /= np.linalg.norm(overhang_direction, axis=1)[:, None]
    tet.cell_data['overhang_direction'] = overhang_direction

    # calculate if cell will print in air by seeing if any cell centers along path to base are higher
    IN_AIR_THRESHOLD = 1
    tet.cell_data['in_air'] = np.full(tet.number_of_cells, False)

    _, paths_to_bottom = nx.multi_source_dijkstra(cell_neighbour_graph, set(bottom_cells))

    # put it in cell data
    tet.cell_data['path_to_bottom'] = np.full((tet.number_of_cells, np.max([len(x) for x in paths_to_bottom.values()])), -1)
    for cell_index, path_to_bottom in paths_to_bottom.items():
        tet.cell_data['path_to_bottom'][cell_index, :len(path_to_bottom)] = path_to_bottom

    # calculate if cell is in air
    for cell_index in tqdm(range(tet.number_of_cells), desc="Vérification surplombs", leave=False):
        path_to_bottom = paths_to_bottom[cell_index]
        if len(path_to_bottom) > 1:
            cell_heights = tet.cell_data['cell_center'][path_to_bottom, 2]
            if np.any(cell_heights > tet.cell_data['cell_center'][cell_index, 2] + IN_AIR_THRESHOLD):
                tet.cell_data['in_air'][cell_index] = True

    return tet

def calculate_tet_attributes(tet):
    '''
    Calculate shared vertices between cells, cell to face & face to cell relations, and bottom cells of the tetrahedral mesh.
    '''
    surface_mesh = tet.extract_surface()

    # put general data in field_data for easy access
    cells = tet.cells.reshape(-1, 5)[:, 1:] # assume all cells have 4 vertices
    tet.add_field_data(cells, "cells")
    cell_vertices = tet.points
    tet.add_field_data(cell_vertices, "cell_vertices")
    faces = surface_mesh.faces.reshape(-1, 4)[:, 1:] # assume all faces have 3 vertices
    tet.add_field_data(faces, "faces")
    face_vertices = surface_mesh.points
    tet.add_field_data(face_vertices, "face_vertices")

    # calculate shared vertices
    shared_vertices = []
    for cell_1, cell_2 in tqdm(tet.field_data["cell_point_neighbours"], desc="Extraction sommets partagés", leave=False):
        shared_vertices_these_faces = np.intersect1d(cells[cell_1], cells[cell_2])
        for vertex in shared_vertices_these_faces:
            shared_vertices.append({
                    "cell_1_index": cell_1,
                    "cell_2_index": cell_2,
                    "cell_1_vertex_index": np.where(cells[cell_1] == vertex)[0][0],
                    "cell_2_vertex_index": np.where(cells[cell_2] == vertex)[0][0],
                })

    # calculate cell to face & face to cell relations
    cell_to_face = {}
    face_to_cell = {face_index: [] for face_index in range(len(faces))}
    cell_to_face_vertices = {}
    face_to_cell_vertices = {}
    
    for cell_vertex_index, cell_vertex in tqdm(enumerate(tet.field_data["cell_vertices"].reshape(-1, 3)), total=len(tet.field_data["cell_vertices"]), desc="Mappage sommets/faces", leave=False):
        face_vertex_index = np.where((face_vertices == cell_vertex).all(axis=1))[0]
        if len(face_vertex_index) == 1:
            cell_to_face_vertices[cell_vertex_index] = face_vertex_index[0]
            face_to_cell_vertices[face_vertex_index[0]] = cell_vertex_index

    for cell_index, cell in tqdm(enumerate(tet.field_data["cells"]), total=len(tet.field_data["cells"]), desc="Mappage cellules/faces", leave=False):
        face_vertex_indices = [cell_to_face_vertices[cell_vertex_index] for cell_vertex_index in cell if cell_vertex_index in cell_to_face_vertices]
        if len(face_vertex_indices) >= 3:
            extracted = surface_mesh.extract_points(face_vertex_indices, adjacent_cells=False)
            if extracted.number_of_cells >= 1:
                cell_to_face[cell_index] = list(extracted.cell_data['vtkOriginalCellIds'])
                for face_index in extracted.cell_data['vtkOriginalCellIds']:
                    face_to_cell[face_index].append(cell_index)

    tet.add_field_data(encode_object(cell_to_face), "cell_to_face")
    tet.add_field_data(encode_object(face_to_cell), "face_to_cell")

    # calculate has_face attribute
    tet.cell_data['has_face'] = np.zeros(tet.number_of_cells)
    for cell_index, face_indices in cell_to_face.items():
        tet.cell_data['has_face'][cell_index] = 1

    tet = update_tet_attributes(tet)

    # calculate bottom cells
    bottom_cells_mask = tet.cell_data['is_bottom']
    bottom_cells = np.where(bottom_cells_mask)[0]

    tet.cell_data['overhang_angle'][bottom_cells] = np.nan

    return tet, bottom_cells_mask, bottom_cells

bottom_cells_mask = None
bottom_cells = None
input_tet, bottom_cells_mask, bottom_cells = calculate_tet_attributes(input_tet)

# find bottom cell groups that are connected
bottom_cell_graph = nx.Graph()
for cell_index in bottom_cells:
    bottom_cell_graph.add_node(cell_index)
cell_point_neighbour_dict = cell_neighbour_dict["point"]
for cell_index in bottom_cells:
    for neighbour in cell_point_neighbour_dict[cell_index]:
        if neighbour in bottom_cells:
            bottom_cell_graph.add_edge(cell_index, neighbour)

bottom_cell_groups = [list(x) for x in list(nx.connected_components(bottom_cell_graph))]

undeformed_tet = input_tet.copy()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Recherche des voisins:   0%|          | 0/3 [00:00<?, ?it/s]
# Création du graphe de proximité:   0%|          | 0/860269 [00:00<?, ?it/s]
# Extraction sommets partagés:   0%|          | 0/860269 [00:00<?, ?it/s]
# Mappage sommets/faces:   0%|          | 0/8070 [00:00<?, ?it/s]
# Mappage cellules/faces:   0%|          | 0/30300 [00:00<?, ?it/s]
# Calcul des normales:   0%|          | 0/11887 [00:00<?, ?it/s]
# Centres des faces:   0%|          | 0/11887 [00:00<?, ?it/s]
# C:\Users\prazl\AppData\Local\Temp\ipykernel_22244\3669491778.py:108: RuntimeWarning: invalid value encountered in divide
#   overhang_direction /= np.linalg.norm(overhang_direction, axis=1)[:, None]
# Vérification surplombs:   0%|          | 0/30300 [00:00<?, ?it/s]

# %%
def planeFit(points):
    """
    p, n = planeFit(points)

    Given an array, points, of shape (d,...)
    representing points in d-dimensional space,
    fit an d-dimensional plane to the points.
    Return a point, p, on the plane (the point-cloud centroid),
    and the normal, n.
    """
    import numpy as np
    from numpy.linalg import svd
    points = np.reshape(points, (np.shape(points)[0], -1))
    assert points.shape[0] <= points.shape[1], "There are only {} points in {} dimensions.".format(points.shape[1], points.shape[0])
    ctr = points.mean(axis=1)
    x = points - ctr[:,np.newaxis]
    M = np.dot(x, x.T)
    return ctr, svd(M)[0][:,-1]

def calculate_path_length_to_base_gradient(tet, MAX_OVERHANG, INITIAL_ROTATION_FIELD_SMOOTHING, SET_INITIAL_ROTATION_TO_ZERO):
    '''
    Calculate the path length to base gradient for each cell in the tetrahedral mesh with respect to the radial direction. This is used to determine the optimal rotation direction for each cell.

    returns: path_length_to_base_gradient. A scalar for each cell in the tetrahedral mesh. This is the gradient in the radial direction of the path length to the closest bottom cell.
    '''
    import numpy as np
    import networkx as nx # Je suppose que c'est importé ailleurs, mais je le note au cas où
    from tqdm.auto import tqdm # <-- La magie pour Jupyter commence ici

    # calculate initial rotation direction for each face
    path_length_to_base_gradient = np.zeros((tet.number_of_cells)) # this is a scalar with respect to the radial direction. ie the vector pointing to the cell center

    # find the path length for every overhang cell to a bottom cell
    cell_distance_to_bottom = np.empty((tet.number_of_cells))
    cell_distance_to_bottom[:] = np.nan
    distances_to_bottom, paths_to_bottom = nx.multi_source_dijkstra(cell_neighbour_graph, set(bottom_cells))# set([x[0] for x in tet.field_data["bottom_cell_groups"]]))
    closest_bottom_cell_indices = np.zeros((tet.number_of_cells), dtype=int)
    
    # Première boucle
    for cell_index in tqdm(range(tet.number_of_cells), desc="Recherche des cellules overhang"):
        face_normal = tet.cell_data["face_normal"][cell_index]

        cell_is_overhang = np.arccos(np.dot(face_normal, [0,0,1])) > np.deg2rad(90+MAX_OVERHANG)
        if cell_is_overhang and cell_index not in bottom_cells:
            closest_bottom_cell_indices[cell_index] = paths_to_bottom[cell_index][0]
            cell_distance_to_bottom[cell_index] = distances_to_bottom[cell_index]

    tet.cell_data["cell_distance_to_bottom"] = cell_distance_to_bottom

    # calculate the gradient of path length to base for each cell
    # Deuxième boucle
    for cell_index in tqdm(range(tet.number_of_cells), desc="Calcul du gradient (radial)"):
        if not np.isnan(cell_distance_to_bottom[cell_index]):
            local_cells = cell_neighbour_dict["edge"][cell_index]
            local_cells = np.hstack((local_cells, cell_index))
            # add neighbours neighbours
            # local_cells = neighbours.copy()
            # for neighbour in neighbours:
            #     local_cells.extend(cell_neighbour_dict["point"][neighbour])
            # local_cells = np.array(list(set(local_cells)))

            local_cell_path_lengths = [cell_distance_to_bottom[local_cell] for local_cell in local_cells]
            local_cell_path_lengths = np.array(local_cell_path_lengths)

            # remove neighbours with path length of nan
            local_cells = np.array(local_cells)[~np.isnan(local_cell_path_lengths)]
            local_cell_path_lengths = local_cell_path_lengths[~np.isnan(local_cell_path_lengths)]

            # if there are less than 3 neighbours with path length, roll to the closest bottom cell
            if len(local_cell_path_lengths) < 3:
                location_to_roll_to = tet.cell_data["cell_center"][closest_bottom_cell_indices[cell_index], :2]

                direction_to_bottom = location_to_roll_to - tet.cell_data["cell_center"][cell_index, :2]
                direction_to_bottom /= np.linalg.norm(direction_to_bottom)

                cell_center = tet.cell_data["cell_center"][cell_index, :2].copy()
                cell_center /= np.linalg.norm(cell_center)

                optimal_rotation_direction = np.dot(cell_center, direction_to_bottom) / np.abs(np.dot(cell_center, direction_to_bottom))
                if np.isnan(optimal_rotation_direction):
                    optimal_rotation_direction = 0

                path_length_to_base_gradient[cell_index] = optimal_rotation_direction

            # if there are 3 or more neighbours with path length, calculate the gradient in the radial direction
            # and use that as the optimal rotation direction
            else:
                points = np.hstack((tet.cell_data["cell_center"][local_cells, :2], local_cell_path_lengths[:, None]))
                _, plane_normal = planeFit(points.T)

                cell_center_direction_normalized = tet.cell_data["cell_center"][cell_index, :2] / np.linalg.norm(tet.cell_data["cell_center"][cell_index, :2])
                gradient_in_radial_direction = np.dot(cell_center_direction_normalized, plane_normal[:2])

                # if the gradient is nan, use the average of the neighbours
                if np.isnan(gradient_in_radial_direction):
                    gradient_in_radial_direction = np.mean(path_length_to_base_gradient[local_cells][~np.isnan(path_length_to_base_gradient[local_cells])])
                    if np.isnan(gradient_in_radial_direction):
                        gradient_in_radial_direction = 0

                path_length_to_base_gradient[cell_index] = gradient_in_radial_direction

    # smooth path_length_to_base_gradient with neighbours
    # not needed because we do neighbour difference minimization in the optimization step?
    if INITIAL_ROTATION_FIELD_SMOOTHING != 0:
        # Troisième boucle (avec sous-boucle)
        for i in tqdm(range(INITIAL_ROTATION_FIELD_SMOOTHING), desc="Lissage global du champ"):
            smoothed_path_length_to_base_gradient = np.zeros((tet.number_of_cells))
            # Sous-boucle : on utilise leave=False pour que la barre de la sous-boucle disparaisse une fois finie
            for cell_index in tqdm(range(tet.number_of_cells), desc=f"Itération de lissage {i+1}", leave=False):
                if path_length_to_base_gradient[cell_index] != 0:
                    neighbours = cell_neighbour_dict["point"][cell_index]
                    local_cells = neighbours.copy()
                    for neighbour in neighbours:
                        local_cells.extend(cell_neighbour_dict["point"][neighbour])
                    local_cells = np.array(list(set(local_cells)))
                    local_cells = local_cells[path_length_to_base_gradient[local_cells]!=0]
                    smoothed_path_length_to_base_gradient[cell_index] = np.mean(path_length_to_base_gradient[local_cells])

            path_length_to_base_gradient = smoothed_path_length_to_base_gradient

    # replace 0 with nan
    if not SET_INITIAL_ROTATION_TO_ZERO:
        path_length_to_base_gradient[path_length_to_base_gradient == 0] = np.nan
    tet.cell_data["path_length_to_base_gradient"] = path_length_to_base_gradient # very sexy

    return path_length_to_base_gradient

# %%
import time
import numpy as np
import pyvista as pv
import torch  # <-- Le sauveur
from scipy.spatial.transform import Rotation as R
from tqdm.notebook import tqdm

def calculate_initial_rotation_field(tet, MAX_OVERHANG, ROTATION_MULTIPLIER, STEEP_OVERHANG_COMPENSATION, INITIAL_ROTATION_FIELD_SMOOTHING, SET_INITIAL_ROTATION_TO_ZERO, MAX_POS_ROTATION, MAX_NEG_ROTATION):
    '''
    Calculate the initial rotation field for each cell in the tetrahedral mesh to make overhangs less than MAX_OVERHANG.
    The direction of rotation ensures the part is printable.
    '''
    initial_rotation_field = np.full((tet.number_of_cells), np.nan)
    initial_rotation_field = np.abs(np.deg2rad(90+MAX_OVERHANG) - tet.cell_data['overhang_angle'])

    # Assuming calculate_path_length_to_base_gradient is defined elsewhere in your notebook
    path_length_to_base_gradient = calculate_path_length_to_base_gradient(tet, MAX_OVERHANG, INITIAL_ROTATION_FIELD_SMOOTHING, SET_INITIAL_ROTATION_TO_ZERO)

    if STEEP_OVERHANG_COMPENSATION:
        initial_rotation_field[tet.cell_data["in_air"]] += 2 * (np.deg2rad(180) - tet.cell_data['overhang_angle'][tet.cell_data["in_air"]])

    initial_rotation_field *= path_length_to_base_gradient
    initial_rotation_field = np.clip(initial_rotation_field*ROTATION_MULTIPLIER, -np.deg2rad(360), np.deg2rad(360))
    initial_rotation_field = np.clip(initial_rotation_field, MAX_NEG_ROTATION, MAX_POS_ROTATION)

    tet.cell_data["initial_rotation_field"] = initial_rotation_field
    return initial_rotation_field

def calculate_rotation_matrices(tet, rotation_field):
    tangential_vectors = np.cross( np.array([0, 0, 1]), tet.cell_data["cell_center"][:, :2])
    tangential_vectors /= np.linalg.norm(tangential_vectors, axis=1)[:, None]
    tangential_vectors[np.isnan(tangential_vectors).any(axis=1)] = [1, 0, 0]
    rotation_matrices = R.from_rotvec(rotation_field[:, None] * tangential_vectors).as_matrix()
    return rotation_matrices

def calculate_unique_vertices_rotated(tet, rotation_field):
    rotation_matrices = calculate_rotation_matrices(tet, rotation_field)
    unique_vertices = np.zeros((tet.number_of_cells, 4, 3))
    for cell_index, cell in enumerate(tet.field_data["cells"]):
        unique_vertices[cell_index] = tet.field_data["cell_vertices"][cell]

    cell_centers = tet.cell_data["cell_center"]
    unique_vertices_rotated = cell_centers.reshape(-1, 1, 3, 1) + rotation_matrices.reshape(-1, 1, 3, 3) @ (unique_vertices.reshape(-1, 4, 3, 1) - cell_centers.reshape(-1, 1, 3, 1))
    return unique_vertices_rotated

def apply_rotation_field_unique_vertices(tet, rotation_field):
    unique_vertices_rotated = calculate_unique_vertices_rotated(tet, rotation_field)
    unique_cells = np.zeros((tet.number_of_cells, 5), dtype=int)
    unique_cells[:, 0] = 4
    unique_cells[:, 1:] = np.arange(tet.number_of_cells*4).reshape(-1, 4)
    new_tet = pv.UnstructuredGrid(unique_cells.flatten(), np.full(tet.number_of_cells, pv.CellType.TETRA), unique_vertices_rotated.reshape(-1, 3))
    return new_tet

def apply_rotation_field(tet, rotation_field):
    new_vertices = np.zeros((tet.number_of_points, 3))
    vertices_count = np.zeros((tet.number_of_points))
    for cell in tet.field_data["cells"]:
        vertices_count[cell] += 1

    unique_vertices_rotated = calculate_unique_vertices_rotated(tet, rotation_field)
    for cell_index, vertices in enumerate(unique_vertices_rotated):
        for i, vertex in enumerate(vertices):
            new_vertices[tet.field_data["cells"][cell_index, i]] += vertex.T[0] / vertices_count[tet.field_data["cells"][cell_index][i]]

    new_tet = pv.UnstructuredGrid(tet.cells, np.full(tet.number_of_cells, pv.CellType.TETRA), new_vertices)
    return new_tet

def optimize_rotations(tet, NEIGHBOUR_LOSS_WEIGHT, MAX_OVERHANG, ROTATION_MULTIPLIER, ITERATIONS, SAVE_GIF, STEEP_OVERHANG_COMPENSATION, INITIAL_ROTATION_FIELD_SMOOTHING, SET_INITIAL_ROTATION_TO_ZERO, MAX_POS_ROTATION, MAX_NEG_ROTATION):
    
    initial_rotation_field = calculate_initial_rotation_field(tet, MAX_OVERHANG, ROTATION_MULTIPLIER, STEEP_OVERHANG_COMPENSATION, INITIAL_ROTATION_FIELD_SMOOTHING, SET_INITIAL_ROTATION_TO_ZERO, MAX_POS_ROTATION, MAX_NEG_ROTATION)
    
    # --- DÉBUT DE LA ZONE GPU (PyTorch) ---
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    if device.type == "cpu":
        print("⚠️ AVERTISSEMENT : CUDA non détecté. Le calcul se fera sur CPU.")

    # 1. Envoi des données statiques sur le GPU (UNE SEULE FOIS)
    cell_face_neighbours = torch.tensor(tet.field_data["cell_face_neighbours"], dtype=torch.long, device=device)
    initial_rot_gpu = torch.tensor(initial_rotation_field, dtype=torch.float32, device=device)
    
    # Masque pour ignorer les NaN
    valid_mask = ~torch.isnan(initial_rot_gpu)

    # 2. Variable à optimiser (équivalent au smoothed_rotation_field)
    # On l'initialise à zéro et on demande à PyTorch de suivre les gradients
    rotation_field_gpu = torch.zeros(tet.number_of_cells, dtype=torch.float32, device=device, requires_grad=True)

    # Utilisation de l'optimiseur Adam (très performant sur GPU pour ce type de perte)
    optimizer = torch.optim.Adam([rotation_field_gpu], lr=0.05)

    pbar = tqdm(total=ITERATIONS, desc="Optimisation GPU", unit="eval")

    # 3. Boucle d'optimisation 100% GPU (Zéro transfert CPU ici)
    for _ in range(ITERATIONS):
        optimizer.zero_grad()

        # Vectorisation GPU : Pertes liées aux voisins
        diffs = rotation_field_gpu[cell_face_neighbours[:, 0]] - rotation_field_gpu[cell_face_neighbours[:, 1]]
        neighbour_losses = torch.sum((NEIGHBOUR_LOSS_WEIGHT * diffs) ** 2)

        # Vectorisation GPU : Pertes liées à la rotation initiale
        initial_losses = torch.sum((rotation_field_gpu[valid_mask] - initial_rot_gpu[valid_mask]) ** 2)

        # Perte totale
        total_loss = neighbour_losses + initial_losses

        # Rétropropagation magique (Autograd)
        total_loss.backward()
        optimizer.step()
        
        pbar.update(1)

    pbar.close()

    # 4. On rapatrie le résultat final sur le CPU pour que PyVista puisse l'utiliser
    optimized_rotation_field = rotation_field_gpu.detach().cpu().numpy()
    # --- FIN DE LA ZONE GPU ---

    # Génération du GIF APRES l'optimisation si demandé (PyVista tourne sur CPU)
    if SAVE_GIF:
        print("Génération du GIF final...")
        # Note: model_name doit être défini globalement dans ton notebook
        plotter = pv.Plotter(off_screen=True)
        plotter.open_gif(f'gifs/optimize_rotations_result.gif')
        new_tet = apply_rotation_field_unique_vertices(tet, optimized_rotation_field)
        new_tet.cell_data["rotation_field"] = optimized_rotation_field
        mesh_actor = plotter.add_mesh(new_tet, clim=[-np.pi/4, np.pi/4], scalars="rotation_field", lighting=False)
        plotter.write_frame()
        plotter.close()

    return optimized_rotation_field

# --- Configuration et exécution ---
NEIGHBOUR_LOSS_WEIGHT = 20
MAX_OVERHANG = 30
ROTATION_MULTIPLIER = 2
SET_INITIAL_ROTATION_TO_ZERO = False
INITIAL_ROTATION_FIELD_SMOOTHING = 30
MAX_POS_ROTATION = np.deg2rad(3600)
MAX_NEG_ROTATION = np.deg2rad(-3600)
ITERATIONS = 1000 # Augmenté car Adam fait des pas plus petits que Levenberg-Marquardt
SAVE_GIF = True
STEEP_OVERHANG_COMPENSATION = True

# undeformed_tet doit être défini avant cette cellule
rotation_field = optimize_rotations(
    undeformed_tet,
    NEIGHBOUR_LOSS_WEIGHT,
    MAX_OVERHANG,
    ROTATION_MULTIPLIER,
    ITERATIONS,
    SAVE_GIF,
    STEEP_OVERHANG_COMPENSATION,
    INITIAL_ROTATION_FIELD_SMOOTHING,
    SET_INITIAL_ROTATION_TO_ZERO,
    MAX_POS_ROTATION,
    MAX_NEG_ROTATION
)

undeformed_tet_with_rotated_tetrahedrons = apply_rotation_field_unique_vertices(undeformed_tet, rotation_field)
undeformed_tet_with_rotated_tetrahedrons.cell_data["rotation_field"] = rotation_field
undeformed_tet_with_rotated_tetrahedrons.plot(scalars="rotation_field")
# Out:
# Recherche des cellules overhang:   0%|          | 0/30300 [00:00<?, ?it/s]
# Calcul du gradient (radial):   0%|          | 0/30300 [00:00<?, ?it/s]
# Lissage global du champ:   0%|          | 0/30 [00:00<?, ?it/s]
# Itération de lissage 1:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 2:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 3:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 4:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 5:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 6:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 7:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 8:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 9:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 10:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 11:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 12:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 13:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 14:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 15:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 16:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 17:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 18:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 19:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 20:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 21:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 22:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 23:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 24:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 25:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 26:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 27:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 28:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 29:   0%|          | 0/30300 [00:00<?, ?it/s]
# Itération de lissage 30:   0%|          | 0/30300 [00:00<?, ?it/s]
# ⚠️ AVERTISSEMENT : CUDA non détecté. Le calcul se fera sur CPU.
# Optimisation GPU:   0%|          | 0/1000 [00:00<?, ?eval/s]
# Génération du GIF final...
# C:\Users\prazl\AppData\Local\Temp\ipykernel_22244\178818714.py:30: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   tangential_vectors = np.cross( np.array([0, 0, 1]), tet.cell_data["cell_center"][:, :2])
# Widget(value='<iframe src="http://localhost:49996/index.html?ui=P_0x175e99ada30_0&reconnect=auto" class="pyvis…

# %%
# On nettoie tout
# !pip uninstall -y torch torchvision torchaudio

# On installe la version qui a les muscles (CUDA 12.1 est la norme actuelle)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Found existing installation: torch 2.11.0+cpu
# Uninstalling torch-2.11.0+cpu:
#   Successfully uninstalled torch-2.11.0+cpu
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\prazl\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\~orch'.
# You can safely remove it manually.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.

# %% [markdown]
# default
# ```
# NEIGHBOUR_LOSS_WEIGHT = 20 # the larger the weight, the more the rotation field will be smoothed
# MAX_OVERHANG = 30          # the maximum overhang angle in degrees
# ROTATION_MULTIPLIER = 2   # the larger the multiplier, the more the rotation field will be rotated
# SET_INITIAL_ROTATION_TO_ZERO = False # reduces influence of initial rotation field on non-overhanging tetrahedrons. good when initial rotation field is noisy
# ```
#
# benchy upsidedown tilted
# scale: 1.5
# Iteration 1:
# ```
# NEIGHBOUR_LOSS_WEIGHT = 100 # the larger the weight, the more the rotation field will be smoothed
# MAX_OVERHANG = 5          # the maximum overhang angle in degrees
# ROTATION_MULTIPLIER = 1   # the larger the multiplier, the more the rotation field will be rotated
# SET_INITIAL_ROTATION_TO_ZERO = True # reduces influence of initial rotation field on non-overhanging tetrahedrons. good when initial rotation field is noisy
# INITIAL_ROTATION_FIELD_SMOOTHING = 30
# ```
#
# Iteration 2:
# ```
# NEIGHBOUR_LOSS_WEIGHT = 50 # the larger the weight, the more the rotation field will be smoothed
# MAX_OVERHANG = 5          # the maximum overhang angle in degrees
# ROTATION_MULTIPLIER = 1   # the larger the multiplier, the more the rotation field will be rotated
# SET_INITIAL_ROTATION_TO_ZERO = True # reduces influence of initial rotation field on non-overhanging tetrahedrons. good when initial rotation field is noisy
# INITIAL_ROTATION_FIELD_SMOOTHING = 30
# ```
#
# Iteration 3,4,5:
# ```
# NEIGHBOUR_LOSS_WEIGHT = 50 # the larger the weight, the more the rotation field will be smoothed
# MAX_OVERHANG = 50          # the maximum overhang angle in degrees
# ROTATION_MULTIPLIER = 3   # the larger the multiplier, the more the rotation field will be rotated
# SET_INITIAL_ROTATION_TO_ZERO = True # reduces influence of initial rotation field on non-overhanging tetrahedrons. good when initial rotation field is noisy
# INITIAL_ROTATION_FIELD_SMOOTHING = 30
# ```

# %%
import numpy as np
import pyvista as pv
import networkx as nx
from tqdm.notebook import tqdm  # Import de la barre de progression pour Jupyter

# view the initial rotation field we are trying to optimize towards
# tet.extract_cells(tet.cell_data['overhang_angle'] > np.deg2rad(90 + MAX_OVERHANG)).plot(scalars="initial_rotation_field")
# tet.cell_data['overhang_angle'] > np.deg2rad(90 + MAX_OVERHANG)
# undeformed_tet.plot(scalars="initial_rotation_field")
# undeformed_tet.plot(scalars="in_air")
undeformed_tet.plot(scalars="cell_distance_to_bottom", cpos=[-0.5, -1, -1])
# undeformed_tet.plot(scalars="overhang_angle")
# undeformed_tet.plot(scalars="path_length_to_base_gradient")
# undeformed_tet.plot(scalars=new_tet1.cell_data['rotation_field'])

def show_path_to_base(tet, cell_index, plotter=pv.Plotter()):
    path_to_bottom = tet.cell_data['path_to_bottom'][cell_index]
    first_negative_index = np.where(path_to_bottom == -1)[0][0]
    path_to_bottom = path_to_bottom[:first_negative_index]
    print(path_to_bottom)

    for i in range(len(path_to_bottom)-1):
        path_to_base = pv.Line(tet.cell_data["cell_center"][path_to_bottom[i]], tet.cell_data["cell_center"][path_to_bottom[i+1]])
        plotter.add_mesh(path_to_base, color="red")

    plotter.add_mesh(tet, opacity=0.2)
    plotter.show()

# show_path_to_base(tet, np.where(tet.cell_data['has_face'].astype(bool) & (tet.cell_data["overhang_angle"] > 3))[0][7])

def show_path_to_base_gradient_calculation(tet, cell_indices):
    plotter = pv.Plotter()
    scalar = np.full(tet.number_of_cells, 0.0)

    # Ajout de tqdm ici pour suivre le calcul des gradients
    for cell_index in tqdm(cell_indices, desc="Calcul des gradients"):
        local_cells = cell_neighbour_dict["edge"][cell_index]
        local_cells = np.hstack((local_cells, cell_index))
        local_cells_with_path_lengths = [x for x in local_cells if not np.isnan(tet.cell_data['cell_distance_to_bottom'][x])]
        path_lengths = tet.cell_data['cell_distance_to_bottom'][local_cells_with_path_lengths]

        cell_centers = tet.cell_data["cell_center"][local_cells_with_path_lengths]
        cell_centers_z_is_path_length = cell_centers.copy()
        cell_centers_z_is_path_length[:, 2] = path_lengths - np.min(path_lengths) + np.min(cell_centers[:, 2])
        points = pv.PolyData(cell_centers_z_is_path_length)
        glyph = points.glyph(geom=pv.Sphere(theta_resolution=8, phi_resolution=8, radius=0.1))

        if len(cell_centers_z_is_path_length) < 3:
            continue

        p, n = planeFit(cell_centers_z_is_path_length.T)
        plane = pv.Plane(center=p, direction=n, i_size=4, j_size=4)
        normal_arrow = pv.Arrow(start=p, direction=n, scale=1.5)

        # reflect arrow across xy plane
        reflected_n = -n - 2 * (np.dot(-n, up_vector)) * up_vector

        # extract radial component
        cell_center_direction_normalized = tet.cell_data["cell_center"][cell_index, :2] / np.linalg.norm(tet.cell_data["cell_center"][cell_index, :2])
        gradient_in_radial_direction = np.dot(cell_center_direction_normalized, reflected_n[:2]) * cell_center_direction_normalized
        nozzle_arrow = pv.Arrow(start=tet.cell_data["cell_center"][cell_index], direction=np.hstack((gradient_in_radial_direction, reflected_n[2])), scale=1)


        # plotter.add_mesh(glyph, color="blue", opacity=0.5, )
        # plotter.add_mesh(plane, color="green", opacity=0.2)
        # plotter.add_mesh(normal_arrow, color="orange")
        plotter.add_mesh(nozzle_arrow, color="red")
        
    scalar[local_cells_with_path_lengths] = 0.5
    scalar[cell_index] = 1
    plotter.add_mesh(tet, opacity=0.2, scalars=scalar, cmap="binary")
    plotter.show()

# show_path_to_base_gradient_calculation(undeformed_tet, [np.where(tet.cell_data['has_face'].astype(bool) & (tet.cell_data["overhang_angle"] > 3))[0][1]])
# show_path_to_base_gradient_calculation(undeformed_tet, np.where(tet.cell_data['has_face'].astype(bool) & (tet.cell_data["overhang_angle"] > np.deg2rad(90 + MAX_OVERHANG)))[0])

def show_dijkstras(tet, cell_index):
    plotter = pv.Plotter()#window_size=[3840, 2160])
    lines = []
    for neighbour in tet.field_data["cell_face_neighbours"]:
        lines += [tet.cell_data["cell_center"][neighbour[0]], tet.cell_data["cell_center"][neighbour[1]]]
    mesh = pv.line_segments_from_points(lines)
    plotter.add_mesh(mesh, color="grey", opacity=0.4)

    points = pv.PolyData(tet.cell_data["cell_center"])
    glyph = points.glyph(geom=pv.Sphere(theta_resolution=8, phi_resolution=8, radius=0.1))
    plotter.add_mesh(glyph, color="red", opacity=0.2)

    if cell_index is None:
        plotter.show()
        return

    plotter.camera_position = "xz"

    # run dijkstra's algorithm and visualize
    plotter.open_gif(f'gifs/{model_name}_dijkstra.gif')
    distances, paths = nx.single_source_dijkstra(cell_neighbour_graph, cell_index)
    dijkstra_actors = []
    
    # Ajout de tqdm ici pour la génération des frames du GIF
    distance_range = np.arange(0, tet.cell_data['cell_distance_to_bottom'][cell_index], 0.2)
    for i in tqdm(distance_range, desc="Génération du GIF Dijkstra"):
        nodes_in_range = [node for node, distance in distances.items() if distance < i]
        if len(nodes_in_range) == 0:
            continue
        if set(nodes_in_range) & set(bottom_cells):
            break
        points = pv.PolyData(tet.cell_data["cell_center"][nodes_in_range])
        glyph = points.glyph(geom=pv.Sphere(theta_resolution=8, phi_resolution=8, radius=0.2))
        actor = plotter.add_mesh(glyph, color="blue", opacity=0.4)
        dijkstra_actors.append(actor)
        plotter.write_frame()

    path_to_bottom = tet.cell_data['path_to_bottom'][cell_index]
    first_negative_index = np.where(path_to_bottom == -1)[0][0]
    path_to_bottom = path_to_bottom[:first_negative_index]
    print(path_to_bottom)

    for i in range(len(path_to_bottom)-1):
        path_to_base = pv.Line(tet.cell_data["cell_center"][path_to_bottom[i]], tet.cell_data["cell_center"][path_to_bottom[i+1]])
        plotter.add_mesh(path_to_base, color="blue", line_width=5)

    for actor in dijkstra_actors:
        plotter.remove_actor(actor)

    plotter.write_frame()

    plotter.show()
    plotter.close()

# show_dijkstras(undeformed_tet, np.where(tet.cell_data['has_face'].astype(bool) & (tet.cell_data["overhang_angle"] > 3))[0][1])
# Out:
# Widget(value='<iframe src="http://localhost:64453/index.html?ui=P_0x260975b7470_2&reconnect=auto" class="pyvis…

# %%
import numpy as np
import pyvista as pv
import time
from scipy.optimize import least_squares
from scipy.sparse import lil_matrix
from tqdm.notebook import tqdm  # ⬅️ Import de la barre de progression pour Jupyter

N = np.eye(4) - 1/4 * np.ones((4, 4)) # the N matrix centers the vertices of a tetrahedron around the origin

save_gif_i = 0

def calculate_deformation(tet, rotation_field, ITERATIONS, SAVE_GIF):
    '''
    Try to find the optimal deformation of the tetrahedral mesh to make cells have the same rotation as
    the given rotation field.

    Our parameters are the vertices of the deformed mesh.
    '''

    new_vertices = tet.points.copy()

    params = new_vertices.flatten()

    rotation_matrices = calculate_rotation_matrices(tet, rotation_field)

    # Extract old vertices for all cells
    old_vertices = tet.field_data["cell_vertices"][tet.field_data["cells"]]
    # Apply the transformation for all cells
    old_vertices_transformed = np.einsum('ijk,ikl->ijl', rotation_matrices, (N @ old_vertices).transpose(0, 2, 1))

    plotter = pv.Plotter(off_screen=True)

    if SAVE_GIF:
        # Assure-toi que la variable model_name est bien définie dans ton scope global !
        plotter.open_gif(f'gifs/{model_name}_calculate_deformation.gif')

    # ⬅️ INITIALISATION DE LA BARRE DE PROGRESSION
    # On utilise ITERATIONS comme total, car c'est le max_nfev (nombre max d'évaluations)
    pbar = tqdm(total=ITERATIONS, desc="Évaluations de la fonction")

    def save_gif(new_vertices):
        global save_gif_i
        save_gif_i += 1

        if save_gif_i % 10 != 0:
            return

        new_tet = pv.UnstructuredGrid(tet.cells, np.full(tet.number_of_cells, pv.CellType.TETRA), new_vertices)
        mesh_actor = plotter.add_mesh(new_tet)
        plotter.write_frame()
        plotter.remove_actor(mesh_actor)


    def objective_function(params):
        start_time = time.time()
        
        # ⬅️ MISE À JOUR DE LA BARRE DE PROGRESSION À CHAQUE APPEL
        pbar.update(1)

        new_vertices = params[:tet.number_of_points * 3].reshape(-1, 3)

        if SAVE_GIF:
            save_gif(new_vertices)

        # Apply transformation for the new vertices
        new_vertices_transformed = (N @ new_vertices[tet.field_data["cells"]]).transpose(0, 2, 1)

        # Calculate position compatibility loss using vectorized operations
        position_losses = np.linalg.norm(new_vertices_transformed - old_vertices_transformed, axis=(1, 2))**2

        # print(f"Objective function took {time.time() - start_time} seconds")
        return position_losses

    def objective_jacobian(params):
        start_time = time.time()

        # Initialize Jacobian matrix
        J = lil_matrix((tet.number_of_cells, len(params)), dtype=np.float32)

        # Extract parameters
        new_vertices = params[:tet.number_of_points * 3].reshape(-1, 3)

        # Extract old vertices for all cells
        old_vertices = tet.field_data["cell_vertices"][tet.field_data["cells"]]

        # Apply the transformation for old and new vertices
        new_vertices_transformed = (N @ new_vertices[tet.field_data["cells"]]).transpose(0, 2, 1)

        # Compute the difference between transformed new and old vertices
        diff = new_vertices_transformed - old_vertices_transformed  # shape: (num_cells, 3, num_vertices_per_cell)

        # Reshape diff for easier broadcasting
        diff = diff.transpose(0, 2, 1)  # shape: (num_cells, num_vertices_per_cell, 3)

        # Now, for each cell, update the corresponding rows in the Jacobian
        cell_indices = np.repeat(np.arange(tet.number_of_cells), len(tet.field_data["cells"][0]))  # Cell indices repeated per vertex
        vertex_indices = np.ravel(tet.field_data["cells"])  # Flatten the cell-to-vertex mapping

        # For each component x, y, z in the vertex, update the Jacobian
        for dim in range(3):
            J[cell_indices, vertex_indices * 3 + dim] = 2 * diff[:, :, dim].ravel()

        # print(f"Objective jacobian took {time.time() - start_time} seconds")
        return J.tocsr()

    def jac_sparsity():
        sparsity = lil_matrix((tet.number_of_cells, len(params)), dtype=np.int8)

        cell_indices = np.repeat(np.arange(tet.number_of_cells), len(tet.field_data["cells"][0]))
        vertex_indices = np.ravel(tet.field_data["cells"])

        for dim in range(3):
            sparsity[cell_indices, vertex_indices * 3 + dim] = 1

        return sparsity.tocsr()

    result = least_squares(objective_function,
                    params,
                    max_nfev=ITERATIONS,
                    verbose=2, # ⚠️ Note: Tu peux passer ça à 0 si le texte de scipy "pollue" l'affichage de ta barre tqdm
                    jac=objective_jacobian,
                    jac_sparsity=jac_sparsity(),
                    method='trf',
                    x_scale='jac',
                    )

    # ⬅️ FERMETURE DE LA BARRE UNE FOIS L'OPTIMISATION TERMINÉE
    pbar.close()
    plotter.close()

    return result.x[:tet.number_of_points*3].reshape(-1, 3)

# --- Exécution ---
ITERATIONS = 1000
SAVE_GIF = True

# N'oublie pas d'avoir tes variables `undeformed_tet` et `rotation_field` définies avant
new_vertices = calculate_deformation(undeformed_tet, rotation_field, ITERATIONS, SAVE_GIF)
deformed_tet = pv.UnstructuredGrid(undeformed_tet.cells, np.full(undeformed_tet.number_of_cells, pv.CellType.TETRA), new_vertices)
deformed_tet.plot()

for key in undeformed_tet.field_data.keys():
    deformed_tet.field_data[key] = undeformed_tet.field_data[key]
for key in undeformed_tet.cell_data.keys():
    deformed_tet.cell_data[key] = undeformed_tet.cell_data[key]
deformed_tet = update_tet_attributes(deformed_tet)
# Out:
# C:\Users\prazl\AppData\Local\Temp\ipykernel_22892\1546037789.py:46: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   tangential_vectors = np.cross( np.array([0, 0, 1]), tet.cell_data["cell_center"][:, :2])
# Évaluations de la fonction:   0%|          | 0/1000 [00:00<?, ?it/s]
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3
#       963            970        3.4269e+02      1.92e-01       7.40e-01       6.31e-01
#       964            971        3.4250e+02      1.93e-01       7.40e-01       6.30e-01
#       965            972        3.4231e+02      1.91e-01       7.41e-01       6.30e-01
#       966            973        3.4211e+02      1.93e-01       7.41e-01       6.29e-01
#       967            974        3.4192e+02      1.91e-01       7.42e-01       6.29e-01
#       968            975        3.4173e+02      1.92e-01       7.42e-01       6.28e-01
#       969            976        3.4154e+02      1.90e-01       7.43e-01       6.28e-01
#       970            977        3.4135e+02      1.91e-01       7.43e-01       6.27e-01
#       971            978        3.4116e+02      1.89e-01       7.44e-01       6.27e-01
#       972            979        3.4097e+02      1.91e-01       7.44e-01       6.26e-01
#       973            980        3.4078e+02      1.89e-01       7.45e-01       6.26e-01
#       974            981        3.4059e+02      1.90e-01       7.45e-01       6.25e-01
#       975            982        3.4040e+02      1.88e-01       7.46e-01       6.25e-01
#       976            983        3.4021e+02      1.90e-01       7.46e-01       6.24e-01
#       977            984        3.4003e+02      1.88e-01       7.47e-01       6.24e-01
#       978            985        3.3984e+02      1.89e-01       7.47e-01       6.24e-01
#       979            986        3.3965e+02      1.87e-01       7.48e-01       6.23e-01
#       980            987        3.3946e+02      1.88e-01       7.48e-01       6.23e-01
#       981            988        3.3927e+02      1.86e-01       7.49e-01       6.22e-01
#       982            989        3.3909e+02      1.88e-01       7.49e-01       6.22e-01
#       983            990        3.3890e+02      1.86e-01       7.49e-01       6.21e-01
#       984            991        3.3871e+02      1.87e-01       7.50e-01       6.21e-01
#       985            992        3.3853e+02      1.85e-01       7.50e-01       6.20e-01
#       986            993        3.3834e+02      1.87e-01       7.50e-01       6.20e-01
#       987            994        3.3816e+02      1.85e-01       7.50e-01       6.19e-01
#       988            995        3.3797e+02      1.86e-01       7.51e-01       6.19e-01
#       989            996        3.3779e+02      1.84e-01       7.51e-01       6.18e-01
#       990            997        3.3760e+02      1.86e-01       7.52e-01       6.18e-01
#       991            998        3.3742e+02      1.84e-01       7.52e-01       6.18e-01
#       992            999        3.3723e+02      1.85e-01       7.52e-01       6.17e-01
#       993           1000        3.3705e+02      1.83e-01       7.53e-01       6.17e-01
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 3.8120e+04, final cost 3.3705e+02, first-order optimality 6.17e-01.
# Widget(value='<iframe src="http://localhost:64453/index.html?ui=P_0x26097c49580_5&reconnect=auto" class="pyvis…
# Calcul des normales:   0%|          | 0/54134 [00:00<?, ?it/s]
# Centres des faces:   0%|          | 0/54134 [00:00<?, ?it/s]
# C:\Users\prazl\AppData\Local\Temp\ipykernel_22892\3669491778.py:108: RuntimeWarning: invalid value encountered in divide
#   overhang_direction /= np.linalg.norm(overhang_direction, axis=1)[:, None]
# Vérification surplombs:   0%|          | 0/133013 [00:00<?, ?it/s]

# %% [markdown]
# Run below to do another iteration

# %%
undeformed_tet = deformed_tet.copy()

# %% [markdown]
# Run below when finished deforming to save mesh as STL

# %%
# make origin center bottom of bounding box
x_min, x_max, y_min, y_max, z_min, z_max = deformed_tet.bounds
offsets_applied = np.array([(x_min + x_max) / 2, (y_min + y_max) / 2, z_min])
deformed_tet.points -= offsets_applied

deformed_tet.extract_surface().save(f'output_models/{model_name}_deformed_tet.stl')

# %%
# save to pickle
with open(f'pickle_files/deformed_{model_name}.pkl', 'wb') as f:
    pickle.dump(deformed_tet, f)

# %% [markdown]
# # Now, go and slice the stl file in Cura!
#
# Settings:
# - Make the printer origin at the center of the buildplate
# - Dont use any pre/post scripts, z hop, etc. The config I use is provided in the github repo
# - Autoplace the model at the center by clicking "Arrange All Models"

# %%
deformed_tet = pickle.load(open(f'pickle_files/deformed_{model_name}.pkl', 'rb'))

# %%
import numpy as np
from tqdm.notebook import tqdm

def tetrahedron_volume(p1, p2, p3, p4):
    '''
    Calculate the volume of the tetrahedron formed by four points
    '''
    mat = np.vstack([p2 - p1, p3 - p1, p4 - p1])
    return np.abs(np.linalg.det(mat)) / 6

def calc_barycentric_coordinates(tet_a, tet_b, tet_c, tet_d, point):
    '''
    Calculate the barycentric coordinates of a point in a tetrahedron. This is used to interpolate
    parameters from the vertices of the tetrahedron to a point within the tetrhedron.
    '''
    total_volume = tetrahedron_volume(tet_a, tet_b, tet_c, tet_d)

    if total_volume == 0:
        raise ValueError("The points do not form a valid tetrahedron (zero volume).")

    # Calculate the sub-volumes for each face
    vol_a = tetrahedron_volume(point, tet_b, tet_c, tet_d)
    vol_b = tetrahedron_volume(point, tet_a, tet_c, tet_d)
    vol_c = tetrahedron_volume(point, tet_a, tet_b, tet_d)
    vol_d = tetrahedron_volume(point, tet_a, tet_b, tet_c)

    # Calculate barycentric coordinates as the ratio of sub-volumes to total volume
    lambda_a = vol_a / total_volume
    lambda_b = vol_b / total_volume
    lambda_c = vol_c / total_volume
    lambda_d = vol_d / total_volume

    # The barycentric coordinates should sum to 1
    return np.array([lambda_a, lambda_b, lambda_c, lambda_d])

def project_point_onto_plane(plane_x_axis, plane_y_axis, point):
    projected_x = np.sum(plane_x_axis * point, axis=1)
    projected_y = np.sum(plane_y_axis * point, axis=1)

    return np.array([projected_x, projected_y]).T

# --- NOUVELLE FONCTION AVEC BARRE DE PROGRESSION ---

def traiter_plusieurs_points(tet_a, tet_b, tet_c, tet_d, liste_points):
    '''
    Exemple de traitement par lots avec une barre de progression Jupyter.
    '''
    resultats = []
    
    # tqdm() enveloppe l'itérable (liste_points) pour générer la barre
    for point in tqdm(liste_points, desc="Calcul des coordonnées"):
        coords = calc_barycentric_coordinates(tet_a, tet_b, tet_c, tet_d, point)
        resultats.append(coords)
        
    return np.array(resultats)

# %%
deformed_tet, _, _ = calculate_tet_attributes(deformed_tet)
# Out:
# Extraction sommets partagés:   0%|          | 0/3532637 [00:00<?, ?it/s]
# Mappage sommets/faces:   0%|          | 0/36160 [00:00<?, ?it/s]
# Mappage cellules/faces:   0%|          | 0/133013 [00:00<?, ?it/s]
# Calcul des normales:   0%|          | 0/54134 [00:00<?, ?it/s]
# Centres des faces:   0%|          | 0/54134 [00:00<?, ?it/s]
# C:\Users\prazl\AppData\Local\Temp\ipykernel_22892\3669491778.py:108: RuntimeWarning: invalid value encountered in divide
#   overhang_direction /= np.linalg.norm(overhang_direction, axis=1)[:, None]
# Vérification surplombs:   0%|          | 0/133013 [00:00<?, ?it/s]

# %%
# !pip install cupy-cuda12x
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cupy-cuda12x in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (14.0.1)
# Requirement already satisfied: numpy<2.6,>=2.0 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cupy-cuda12x) (2.4.0)
# Requirement already satisfied: cuda-pathfinder==1.*,>=1.3.3 in c:\users\prazl\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cupy-cuda12x) (1.5.3)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\prazl\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from pygcode import Line
import os
# Remplace '12.x' par ta version de CUDA (ex: 12.1, 12.4, 11.8)
os.add_dll_directory(r"C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.x\bin")
import time
import numpy as np
import cupy as cp # Le boss du game GPU
from tqdm.notebook import tqdm

SEG_SIZE = 0.6 # mm
MAX_ROTATION = 30 # degrees
MIN_ROTATION = -130 # degrees
NOZZLE_OFFSET = 42 # mm actually 41.5

# On extrait les données du maillage vers le GPU
input_points_gpu = cp.asarray(input_tet.points)
deformed_points_gpu = cp.asarray(deformed_tet.points)
input_centers_gpu = cp.asarray(input_tet.cell_data["cell_center"])
deformed_centers_gpu = cp.asarray(deformed_tet.cell_data["cell_center"])

# find how each vertex in tet has been transformed (Directement sur GPU)
vertex_transformations_gpu = deformed_points_gpu - input_points_gpu

# calculate tangential vectors (axis of rotation) for each cell
z_axis = cp.array([0, 0, 1])
tangential_vectors_gpu = cp.cross(z_axis, input_centers_gpu[:, :2])
norms = cp.linalg.norm(tangential_vectors_gpu, axis=1)[:, None]
tangential_vectors_gpu = cp.where(norms == 0, cp.array([1.0, 0.0, 0.0]), tangential_vectors_gpu / norms)
# replace nan with [1,0,0] (géré par le conditionnel ci-dessus si division par zéro)

# calculate rotation for each vertex and cell
num_cells_per_vertex_gpu = cp.zeros((input_tet.number_of_points))
# Pour ce calcul d'occurrences, on utilise bincount qui est ultra optimisé sur GPU
cells_flat = cp.asarray(input_tet.field_data["cells"]).flatten()
occurrences = cp.bincount(cells_flat, minlength=input_tet.number_of_points)
num_cells_per_vertex_gpu = occurrences

vertex_rotations_gpu = cp.zeros((deformed_tet.number_of_points))
cell_rotations_gpu = cp.zeros((deformed_tet.number_of_cells))

# Vectorisation de l'algorithme de Kabsch pour éviter la boucle for massive
print("Calcul des rotations sur GPU...")
new_vertices_all = cp.asarray(deformed_tet.field_data["cell_vertices"])
old_vertices_all = cp.asarray(input_tet.field_data["cell_vertices"])

new_vertices_centered = new_vertices_all - deformed_centers_gpu[:, None, :]
old_vertices_centered = old_vertices_all - input_centers_gpu[:, None, :]

# Projection vectorisée
norms_centers = cp.linalg.norm(input_centers_gpu[:, :2], axis=1)
plane_x_vectors = cp.zeros_like(input_centers_gpu)
mask = norms_centers > 0
plane_x_vectors[mask, :2] = input_centers_gpu[mask, :2] / norms_centers[mask, None]
plane_y_vector = cp.array([0, 0, 1])

# Note: project_point_onto_plane doit accepter des tenseurs CuPy (cp). 
# Je pars du principe que sa logique mathématique est compatible avec les arrays multidimensionnels CuPy.
new_vertices_projected = project_point_onto_plane(plane_x_vectors, plane_y_vector, new_vertices_centered)
old_vertices_projected = project_point_onto_plane(plane_x_vectors, plane_y_vector, old_vertices_centered)

# Covariance et SVD en batch sur GPU
covariance_matrices = cp.einsum('cji,cjk->cik', new_vertices_projected, old_vertices_projected)
U, _, Vt = cp.linalg.svd(covariance_matrices)
rotation_matrices = cp.matmul(U, Vt)

# Extraction des angles vectorisée
rotations = -cp.arccos(cp.clip(rotation_matrices[:, 0, 0], -1.0, 1.0))
rotations = cp.where(rotation_matrices[:, 1, 0] < 0, -rotations, rotations)
cell_rotations_gpu = cp.clip(rotations, cp.deg2rad(MIN_ROTATION), cp.deg2rad(MAX_ROTATION))

# Dispatch des rotations sur les sommets (Scatter add sur GPU)
cp.scatter_add(vertex_rotations_gpu, cells_flat, cp.repeat(cell_rotations_gpu, 4) / num_cells_per_vertex_gpu[cells_flat])

# calculate z squish scale
tet_rotation_matrices_gpu = calculate_rotation_matrices(input_tet, cell_rotations_gpu) # À adapter pour CuPy si custom
z_squish_scales_gpu = cp.full((deformed_tet.number_of_cells), cp.nan)

unwarped_vertices_rotated = cp.einsum('cij,ckj->cki', tet_rotation_matrices_gpu, old_vertices_all)

# Note : tetrahedron_volume doit gérer les arrays CuPy batchés.
vols_unwarped = tetrahedron_volume_batch(unwarped_vertices_rotated) # Version vectorisée hypothétique
vols_warped = tetrahedron_volume_batch(new_vertices_all)
z_squish_scales_gpu = vols_unwarped / vols_warped

# --- RETOUR TEMPORAIRE AU CPU JUSTE POUR PARSER LE TEXTE (Inévitable) ---
pos = np.array([0., 0., 20.])
feed = 5000
gcode_points = []
with open(f'input_gcode/{model_name}_deformed_tet.gcode', 'r') as fh:
    lines = fh.readlines()
    for line_text in tqdm(lines, desc="Lecture du Gcode (CPU)"):
        line = Line(line_text)
        if not line.block.gcodes: continue

        for gcode in sorted(line.block.gcodes):
            if gcode.word in ["G01", "G00"]:
                prev_pos = pos.copy()
                if gcode.X is not None: pos[0] = gcode.X
                if gcode.Y is not None: pos[1] = gcode.Y
                if gcode.Z is not None: pos[2] = gcode.Z

                inv_time_feed = None
                for word in line.block.words:
                    if word.letter == "F": feed = word.value
                
                extrusion = None
                for param in line.block.modal_params:
                    if param.letter == "E": extrusion = param.value

                delta_pos = pos - prev_pos
                distance = np.linalg.norm(delta_pos)
                
                if distance > 0:
                    num_segments = -(-distance // SEG_SIZE)
                    seg_distance = distance / num_segments
                    time_to_complete_move = (1/feed) * seg_distance
                    inv_time_feed = 1/time_to_complete_move if time_to_complete_move != 0 else None

                    for i in range(int(num_segments)):
                        gcode_points.append({
                            "position": (prev_pos + delta_pos * (i+1) / num_segments),
                            "command": gcode.word,
                            "extrusion": extrusion/num_segments if extrusion is not None else None,
                            "inv_time_feed": inv_time_feed,
                            "move_length": seg_distance,
                            "start_position": prev_pos,
                            "end_position": pos,
                            "unsegmented_move_length": distance,
                            "after_retract": False,
                            "feed": feed
                        })
                else:
                    time_to_complete_move = (1/feed) * distance
                    inv_time_feed = 1/time_to_complete_move if time_to_complete_move != 0 else None
                    gcode_points.append({
                        "position": pos.copy(), "command": gcode.word, "extrusion": extrusion,
                        "inv_time_feed": inv_time_feed, "move_length": distance,
                        "unsegmented_move_length": distance, "after_retract": False, "feed": feed
                    })

print("Calcul des cellules contenant les points (CPU - via la lib de maillage)...")
gcode_positions_np = np.array([point["position"] for point in gcode_points])
gcode_points_containing_cells = deformed_tet.find_containing_cell(gcode_positions_np)
gcode_points_closest_cells = deformed_tet.find_closest_cell(gcode_positions_np)

# --- RE-ENVOI SUR GPU POUR L'INTERPOLATION FINALE ---
print("Interpolation barycentrique sur GPU...")
pos_gpu = cp.asarray(gcode_positions_np)
containing_gpu = cp.asarray(gcode_points_containing_cells)
closest_gpu = cp.asarray(gcode_points_closest_cells)

# On garde la logique séquentielle inévitable due à l'imprimante 3D (machine à états)
# Mais on ramène les arrays finaux en NumPy pour la compatibilité avec ton script
vertex_transformations_np = cp.asnumpy(vertex_transformations_gpu)
vertex_rotations_np = cp.asnumpy(vertex_rotations_gpu)
z_squish_scales_np = cp.asnumpy(z_squish_scales_gpu)

new_gcode_points = []
prev_new_position = None
travelling_over_air = False
travelling = False
prev_position = None
prev_rotation = 0
prev_travelling = False
prev_command = "G00"
ROTATION_AVERAGING_ALPHA = 0.2 
RETRACTION_LENGTH = 1.0
ROTATION_MAX_DELTA = np.deg2rad(1)
MAX_EXTRUSION_MULTIPLIER = 10
lost_vertices = []
highest_printed_point = 0

for cell_index, gcode_point in enumerate(tqdm(gcode_points, desc="Transformation finale (Hybride)")):
    position = gcode_point["position"]
    command = gcode_point["command"]
    inv_time_feed = gcode_point["inv_time_feed"]
    extrusion = gcode_point["extrusion"]
    containing_cell_index = gcode_points_containing_cells[cell_index]

    def barycentric_interpolate_to_get_new_position_and_rotation(position, containing_cell_index, command, cell_index):
        if command == "G00" and containing_cell_index == -1: return None, None
        if command == "G01" and containing_cell_index == -1:
            containing_cell_index = gcode_points_closest_cells[cell_index]

        vertiex_indices = deformed_tet.field_data["cells"][containing_cell_index]
        cell_vertices = deformed_tet.field_data["cell_vertices"][vertiex_indices]
        # calc_barycentric_coordinates doit s'exécuter ici
        barycentric_coordinates = calc_barycentric_coordinates(cell_vertices[0], cell_vertices[1], cell_vertices[2], cell_vertices[3], position)

        if np.sum(barycentric_coordinates) > 1.01: return None, None

        transformation = vertex_transformations_np[vertiex_indices] * barycentric_coordinates[:, None]
        transformation = np.sum(transformation, axis=0)
        new_position = position - transformation
        rotation = np.sum(vertex_rotations_np[vertiex_indices] * barycentric_coordinates)
        return new_position, rotation

    dont_smooth_rotation = False
    new_position, rotation = barycentric_interpolate_to_get_new_position_and_rotation(position, containing_cell_index, command, cell_index)
    
    if new_position is None:
        if command == "G01":
            lost_vertices.append(position)
            continue
        elif command == "G00" and not travelling_over_air and prev_new_position is not None:
            new_position = np.array([prev_new_position[0], prev_new_position[1], highest_printed_point]) 
            rotation = max(min(prev_rotation, np.deg2rad(45)), np.deg2rad(-45)) 
            dont_smooth_rotation = True 
            travelling_over_air = True
        elif travelling_over_air:
            continue
        else:
            continue
    else:
        if travelling_over_air:
            new_position[2] = highest_printed_point
            rotation = max(min(rotation, np.deg2rad(45)), np.deg2rad(-45)) 
            dont_smooth_rotation = True 
        travelling_over_air = False

    extrusion_multiplier = 1
    if extrusion is not None and extrusion != RETRACTION_LENGTH and extrusion != -RETRACTION_LENGTH:
        extrusion_multiplier = extrusion_multiplier * z_squish_scales_np[containing_cell_index]
        extrusion = extrusion * min(extrusion_multiplier, MAX_EXTRUSION_MULTIPLIER)
    elif extrusion == -RETRACTION_LENGTH:
        travelling = True
    elif extrusion == RETRACTION_LENGTH:
        travelling = False
        
    if prev_rotation is not None and not dont_smooth_rotation:
        rotation = ROTATION_AVERAGING_ALPHA * rotation + (1 - ROTATION_AVERAGING_ALPHA) * prev_rotation

    if prev_rotation is not None and prev_new_position is not None and np.abs(rotation - prev_rotation) > ROTATION_MAX_DELTA:
        delta_rotation = rotation - prev_rotation
        num_interpolations = int(np.abs(delta_rotation) / ROTATION_MAX_DELTA) + 1
        delta_pos = new_position - prev_new_position
        for i in range(num_interpolations):
            new_gcode_points.append({
                "position": prev_new_position + (delta_pos * ((i+1) / num_interpolations)),
                "original_position": position,
                "rotation": prev_rotation + (delta_rotation * ((i+1) / num_interpolations)),
                "command": prev_command,
                "extrusion": extrusion/num_interpolations if extrusion is not None else None,
                "inv_time_feed": inv_time_feed * num_interpolations if inv_time_feed is not None else None,
                "extrusion_multiplier": extrusion_multiplier,
                "feed": gcode_point["feed"],
                "travelling": prev_travelling
            })
    else:
        new_gcode_points.append({
            "position": new_position, "original_position": position, "rotation": rotation,
            "command": command, "extrusion": extrusion, "inv_time_feed": inv_time_feed,
            "extrusion_multiplier": extrusion_multiplier, "feed": gcode_point["feed"],
            "travelling": travelling
        })

    prev_rotation = rotation
    prev_new_position = new_position.copy()
    prev_travelling = travelling
    prev_command = command

    if command == "G01" and extrusion is not None and extrusion > 0 and (highest_printed_point != 0 or new_position[2] < 1):
        highest_printed_point = max(highest_printed_point, new_position[2])

print(f"Lost {len(lost_vertices)} vertices")
# Out:
# ---------------------------------------------------------------------------
# DynamicLibNotFoundError                   Traceback (most recent call last)
# Cell In[27], line 19
#      16 deformed_centers_gpu = cp.asarray(deformed_tet.cell_data["cell_center"])
#      18 # find how each vertex in tet has been transformed (Directement sur GPU)
# ---> 19 vertex_transformations_gpu = deformed_points_gpu - input_points_gpu
#      21 # calculate tangential vectors (axis of rotation) for each cell
#      22 z_axis = cp.array([0, 0, 1])
#
# File cupy/_core/core.pyx:1497, in cupy._core.core._ndarray_base.__sub__()
#
# File cupy/_core/_kernel.pyx:1380, in cupy._core._kernel.ufunc.__call__()
#
# File cupy/_core/_kernel.pyx:1407, in cupy._core._kernel.ufunc._get_ufunc_kernel()
#
# File cupy/_core/_kernel.pyx:1077, in cupy._core._kernel._get_ufunc_kernel()
#
# File cupy/_core/_kernel.pyx:103, in cupy._core._kernel._get_simple_elementwise_kernel()
#
# File cupy/_core/_kernel.pyx:91, in cupy._core._kernel._get_simple_elementwise_kernel_from_code()
#
# File cupy/_core/core.pyx:2550, in cupy._core.core.compile_with_cache()
#
# File cupy/_core/core.pyx:2497, in cupy._core.core.assemble_cupy_compiler_options()
#
# File cupy_backends/cuda/libs/nvrtc.pyx:57, in cupy_backends.cuda.libs.nvrtc.getVersion()
#
# File cupy_backends/cuda/libs/_cnvrtc.pxi:72, in cupy_backends.cuda.libs.nvrtc.initialize()
#
# File cupy_backends/cuda/libs/_cnvrtc.pxi:75, in cupy_backends.cuda.libs.nvrtc._initialize()
#
# File cupy_backends/cuda/libs/_cnvrtc.pxi:125, in cupy_backends.cuda.libs.nvrtc._get_softlink()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cuda\pathfinder\_dynamic_libs\load_nvidia_dynamic_lib.py:303, in load_nvidia_dynamic_lib(libname)
#     298 if libname not in _ALL_SUPPORTED_LIBNAMES:
#     299     raise DynamicLibNotAvailableError(
#     300         f"Library name {libname!r} is known but not available on {_PLATFORM_NAME}. "
#     301         f"Supported names on {_PLATFORM_NAME}: {sorted(_ALL_SUPPORTED_LIBNAMES)}"
#     302     )
# --> 303 return _load_lib_no_cache(libname)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cuda\pathfinder\_dynamic_libs\load_nvidia_dynamic_lib.py:190, in _load_lib_no_cache(libname)
#     187     if canary_abs_path is not None:
#     188         return LOADER.load_with_abs_path(desc, canary_abs_path, "system-ctk-root")
# --> 190 ctx.raise_not_found()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cuda\pathfinder\_dynamic_libs\search_steps.py:66, in SearchContext.raise_not_found(self)
#      64 err = ", ".join(self.error_messages)
#      65 att = "\n".join(self.attachments)
# ---> 66 raise DynamicLibNotFoundError(f'Failure finding "{self.lib_searched_for}": {err}\n{att}')
#
# DynamicLibNotFoundError: Failure finding "nvrtc*.dll": No such file: nvrtc*.dll, No such file: nvrtc*.dll

# %%
prev_r = 0
prev_theta = 0
prev_z = 20

theta_accum = 0

# save transformed gcode
with open(f'output_gcode/{model_name}.gcode', 'w') as fh:
    # write header
    fh.write("G94 ; mm/min feed  \n")
    fh.write("G28 ; home \n")
    fh.write("M83 ; relative extrusion \n")
    fh.write("G1 E10 ; prime extruder \n")
    fh.write("G94 ; mm/min feed \n")
    fh.write("G90 ; absolute positioning \n")
    fh.write(f"G0 C{prev_theta} X{prev_r} Z{prev_z} B0 ; go to start \n")
    fh.write("G93 ; inverse time feed \n")

    for i, point in enumerate(new_gcode_points):
        position = point["position"]
        rotation = point["rotation"]

        if np.all(np.isnan(position)):
            continue

        if position[2] < 0:
            continue

        z_hop = 0
        if point["travelling"]:
            z_hop = 1

        # convert to polar coordinates
        r = np.linalg.norm(position[:2])
        theta = np.arctan2(position[1], position[0])
        z = position[2]

        # compensate for nozzle offset
        r += -np.sin(rotation) * (NOZZLE_OFFSET + z_hop)
        z += (np.cos(rotation) - 1) * (NOZZLE_OFFSET + z_hop) + z_hop

        delta_theta = theta - prev_theta
        if delta_theta > np.pi:
            delta_theta -= 2*np.pi
        if delta_theta < -np.pi:
            delta_theta += 2*np.pi

        theta_accum += delta_theta

        string = f"{point['command']} C{np.rad2deg(theta_accum):.5f} X{r:.5f} Z{z:.5f} B{np.rad2deg(rotation):.5f}" # polar printer
        # string = f"{point['command']} X{position[0]:.5f} Y{position[1]:.5f} Z{position[2]} B{np.rad2deg(rotation):.5f}" # cartesian printer (3 axis)

        if point["extrusion"] is not None:
            string += f" E{point['extrusion']:.4f}"

        no_feed_value = False
        if point["inv_time_feed"] is not None:
            string += f" F{(point['inv_time_feed']):.4f}"
        else:
            string += f" F20000"
            fh.write(f"G94\n")
            no_feed_value = True

        fh.write(string + "\n")

        if no_feed_value:
            fh.write(f"G93\n") # back to inv feed

        # update previous values
        prev_r = r
        prev_theta = theta
        prev_z = z

# %%
# plot new_gcode_points using pyvista
temp = np.array([point["position"] for point in new_gcode_points])
#temp = np.array(a)
temp = pv.PolyData(temp)
temp.cell_data["rotation"] = np.array([np.rad2deg(point["rotation"]) for point in new_gcode_points])
temp.cell_data["travelling"] = np.array([point["travelling"] for point in new_gcode_points])
temp.cell_data["delta_rotation"] = np.clip(np.array([1] + [np.rad2deg(new_gcode_points[i+1]["rotation"] - new_gcode_points[i]["rotation"]) for i in range(len(new_gcode_points)-1)]), -10, 10)
temp.cell_data["command"] = np.array([point["command"] for point in new_gcode_points])
temp.cell_data["feed"] = np.array([min(point["feed"], 10000) for point in new_gcode_points])
temp.cell_data["original_z"] = np.array([point["original_position"][2] for point in new_gcode_points])
temp.cell_data["original_z_bands"] = temp.cell_data["original_z"] % 1
temp.cell_data["extrusion_multiplier"] = np.array([min(point["extrusion_multiplier"], 15) if point["extrusion_multiplier"] is not None else np.nan for point in new_gcode_points])

temp.extract_cells(np.array([point["command"] for point in new_gcode_points]) == "G01").plot(scalars="original_z_bands", cpos=[-0.5, -1, 0.5], point_size=10)
# .extract_cells(np.array([point["command"] for point in new_gcode_points]) == "G01")
# Out:
# Widget(value='<iframe src="http://localhost:60801/index.html?ui=P_0x2b937e1a060_5&reconnect=auto" class="pyvis…

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# plot the gcode
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
cmap = plt.get_cmap('viridis')
rotation_normalized = temp.cell_data["rotation"] / np.max(np.abs(temp.cell_data["rotation"]),axis=0)
colors = cmap(rotation_normalized)
# for i in np.arange(len(temp.points)-1):
#     ax.plot(
#         [temp.points[i,0],temp.points[i+1,0]],
#         [temp.points[i,1],temp.points[i+1,1]],
#         [temp.points[i,2],temp.points[i+1,2]],
#         c=colors[i],
#         markersize=0.8, linewidth=0.9, marker='.', alpha=0.5)
# plot G00 moves in different color
g00_indices = np.where(temp.cell_data["command"] == "G00")[0]
g01_indices = np.where(temp.cell_data["command"] == "G01")[0]
ax.plot(temp.points[g00_indices,0], temp.points[g00_indices,1], temp.points[g00_indices,2], markersize=0.4, linewidth=0.3, marker=".", alpha=0.5, color="red")
ax.plot(temp.points[g01_indices,0], temp.points[g01_indices,1], temp.points[g01_indices,2], markersize=0.4, linewidth=0.3, marker=".", alpha=0.5, color="blue")
ax.set_box_aspect((np.ptp(temp.points[:,0]), np.ptp(temp.points[:,1]), np.ptp(temp.points[:,2])))
plt.show()
